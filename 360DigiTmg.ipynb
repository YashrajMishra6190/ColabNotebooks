# %% [markdown]
# <a href="https://colab.research.google.com/github/YashrajMishra6190/ColabNotebooks/blob/main/360DigiTmg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Medical Inventory Optimization
#
# ---
# Client: Pharmacy of a leading Hospital in India
#
# Medical Inventory Optimization:
#
# Business Problem: Bounce rate is increasing significantly leading to patient dissatisfaction.
#
# Business Objective: Minimize Bounce Rate
# Business Constraint: Minimize Inventory Cost
#
# Business Success Criteria: Reduce bounce rate by at least 30%
#
# Economic Success Criteria: Increase revenue by at least 20 lac INR by reducing bounce rate.
#
# ---
# Key Features:
#
# -> First Moment Business Decision (Mean, Median, Mode)
#
# -> Second Moment Business Decision (Variance, Standard Deviation, Range)
#
# -> Third Moment Business Decision (Skewness)
#
# -> Fourth Moment Business Decision (Kurtosis)
#
# --------
# Work: Firstly I will find out all the features with the raw dataset after that I will work on the preprcocessed dataset then again find the overall required features and note the conclusion.

# %%
# Importing the libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing dataset
df = pd.read_csv(r'/content/Medical Inventory Optimaization Dataset.csv')

# %%
df.head()
# Out:
#   Typeofsales   Patient_ID    Specialisation         Dept  Dateofbill  \
# 0        Sale  12018098765   Specialisation6  Department1    6-1-2022
# 1        Sale  12018103897   Specialisation7  Department1   7/23/2022
# 2        Sale  12018101123   Specialisation2  Department3   6/23/2022
# 3        Sale  12018079281  Specialisation40  Department1   3/17/2022
# 4        Sale  12018117928   Specialisation5  Department1  12/21/2022
#
#    Quantity  ReturnQuantity  Final_Cost  Final_Sales  RtnMRP Formulation  \
# 0         1               0      55.406       59.260     0.0       Form1
# 1         1               0     768.638      950.800     0.0       Form1
# 2         1               0     774.266     4004.214     0.0       Form2
# 3         2               0      40.798       81.044     0.0       Form1
# 4         1               0      40.434       40.504     0.0       Form1
#
#                             DrugName              SubCat  \
# ...

# %%
df.shape
# Out:
# (14218, 14)

# %% [markdown]
# # Data Collection:
# ----
#
# Data is collected as well as extracted from the different sources and Client {Pharmacy of a leading } provided  the dataset. Now, this dataset contains (df.shape) 14218 rows and 14 columns.

# %% [markdown]
# # First Moment Business Decision
# -----
#   `Measure of Central Tendency`: MEAN, MEDIAN, MODE

# %%
df.columns
# Out:
# Index(['Typeofsales', 'Patient_ID', 'Specialisation', 'Dept', 'Dateofbill',
#        'Quantity', 'ReturnQuantity', 'Final_Cost', 'Final_Sales', 'RtnMRP',
#        'Formulation', 'DrugName', 'SubCat', 'SubCat1'],
#       dtype='object')

# %%
data1 = {
    'column_name' : ['Qunatity', 'ReturnQuantity', 'Final_Cost', 'Final_Sales', 'RtnMRP'],
    'mean_column' : [df['Quantity'].mean(), df['ReturnQuantity'].mean(), df['Final_Cost'].mean(), df['Final_Sales'].mean(), df['RtnMRP'].mean()],
    'median_column' : [df['Quantity'].median(), df['ReturnQuantity'].median(), df['Final_Cost'].median(), df['Final_Sales'].median(), df['RtnMRP'].median()],
    'mode_column' : [df['Quantity'].mode(), df['ReturnQuantity'].mode(), df['Final_Cost'].mode(), df['Final_Sales'].mode(), df['RtnMRP'].mode()]
}

# %%
first_moment = pd.DataFrame(data1)
first_moment
# Out:
#       column_name  mean_column  median_column  \
# 0        Qunatity     2.231748          1.000
# 1  ReturnQuantity     0.291954          0.000
# 2      Final_Cost   124.823957         53.650
# 3     Final_Sales   234.038300         86.424
# 4          RtnMRP    29.126755          0.000
#
#                                     mode_column
# 0           0    1
# Name: Quantity, dtype: int64
# 1     0    0
# Name: ReturnQuantity, dtype: int64
# 2  0    49.352
# Name: Final_Cost, dtype: float64
# 3    0    0.0
# Name: Final_Sales, dtype: float64
# 4         0    0.0
# Name: RtnMRP, dtype: float64

# %%
#Mode value for the categorical Value
data_cat = {
    'column_name' : ['Formulation', 'DrugName' , 'SubCat' , 'SubCat1'],
    'Mode_categorical' : [df['Formulation'].mode(), df['DrugName'].mode(), df['SubCat'].mode(), df['SubCat1'].mode]
}

mode_cat = pd.DataFrame(data_cat)
mode_cat
# Out:
#    column_name                                   Mode_categorical
# 0  Formulation        0    Form1
# Name: Formulation, dtype: object
# 1     DrugName  0    SODIUM CHLORIDE IVF 100ML
# Name: DrugName,...
# 2       SubCat        0    INJECTIONS
# Name: SubCat, dtype: object
# 3      SubCat1  <bound method Series.mode of 0                ...

# %% [markdown]
# # Second Moment Business Decision
# ----
# `Measure of Dispersion`: VARIANCE, Standard Deviation, RANGE

# %%
#range = MAX-MIN

range_q = max(df['Quantity']) - min(df['Quantity'])
range_rq = max(df['ReturnQuantity']) - min(df['ReturnQuantity'])
range_fc = max(df['Final_Cost']) - min(df['Final_Cost'])
range_fs = max(df['Final_Sales']) - min(df['Final_Sales'])
range_rmrp = max(df['RtnMRP']) - min(df['RtnMRP'])

# %%
data2 = {
    'column_name' : ['Qunatity', 'ReturnQuantity', 'Final_Cost', 'Final_Sales', 'RtnMRP'],
    'variance_column' : [df['Quantity'].var(), df['ReturnQuantity'].var(), df['Final_Cost'].var(), df['Final_Sales'].var(), df['RtnMRP'].var()],
    'standard_deviation' : [df['Quantity'].std(), df['ReturnQuantity'].std(), df['Final_Cost'].std(), df['Final_Sales'].std(), df['RtnMRP'].std()],
    'range_column' : [range_q, range_rq, range_fc, range_fs, range_rmrp]
}

# %%
second_moment = pd.DataFrame(data2)
second_moment
# Out:
#       column_name  variance_column  standard_deviation  range_column
# 0        Qunatity        26.337862            5.132043         150.0
# 1  ReturnQuantity         2.700506            1.643322          50.0
# 2      Final_Cost    216023.045394          464.782794       33138.0
# 3     Final_Sales    450592.097666          671.261572       39490.0
# 4          RtnMRP     33219.558938          182.262335        8014.0

# %% [markdown]
# # Third Moment Business Decision
# ---
# `Skewness`

# %%
data3 = {
    'column_name' : ['Qunatity', 'ReturnQuantity', 'Final_Cost', 'Final_Sales', 'RtnMRP'],
    'skewness_column' : [df['Quantity'].skew(), df['ReturnQuantity'].skew(), df['Final_Cost'].skew(), df['Final_Sales'].skew(), df['RtnMRP'].skew()]
}

# %%
third_moment = pd.DataFrame(data3)
third_moment
# Out:
#       column_name  skewness_column
# 0        Qunatity        11.341034
# 1  ReturnQuantity        17.172365
# 2      Final_Cost        34.508215
# 3     Final_Sales        21.006722
# 4          RtnMRP        15.797853

# %% [markdown]
# # Fourth Moment Business Decison
# ---
# `Kurtosis`

# %%
data4 = {
    'column_name' : ['Qunatity', 'ReturnQuantity', 'Final_Cost', 'Final_Sales', 'RtnMRP'],
    'kurtosis_column' : [df['Quantity'].kurt(), df['ReturnQuantity'].kurt(), df['Final_Cost'].kurt(), df['Final_Sales'].kurt(), df['RtnMRP'].kurt()]
}

# %%
fourth_moment = pd.DataFrame(data4)
fourth_moment
# Out:
#       column_name  kurtosis_column
# 0        Qunatity       180.153858
# 1  ReturnQuantity       409.416914
# 2      Final_Cost      2025.866475
# 3     Final_Sales       948.522711
# 4          RtnMRP       403.524941

# %% [markdown]
# # Correlation Matrix

# %%
matrix = df.corr()

#plotting correlation matrix
plt.imshow(matrix, cmap='coolwarm')

#adding colorbar
plt.colorbar()

#extracting variable names
variables = []
for i in matrix.columns:
  variables.append(i)

# Adding labels to the matrix
plt.xticks(range(len(matrix)), variables, rotation=45, ha='right')
plt.yticks(range(len(matrix)), variables)

# Display the plot
plt.show()
# Out:
# <ipython-input-58-52bb412fa56b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matrix = df.corr()

# %% [markdown]
# ## Heatmap for the matrix

# %%
import seaborn as sns
dataplot=sns.heatmap(matrix, annot = True)
plt.show()

# %% [markdown]
# # Handling Missig Value
# ---

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14218 entries, 0 to 14217
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Typeofsales     14218 non-null  object
#  1   Patient_ID      14218 non-null  int64
#  2   Specialisation  14218 non-null  object
#  3   Dept            14218 non-null  object
#  4   Dateofbill      14218 non-null  object
#  5   Quantity        14218 non-null  int64
#  6   ReturnQuantity  14218 non-null  int64
#  7   Final_Cost      14218 non-null  float64
#  8   Final_Sales     14218 non-null  float64
#  9   RtnMRP          14218 non-null  float64
#  10  Formulation     13565 non-null  object
#  11  DrugName        12550 non-null  object
#  12  SubCat          12550 non-null  object
#  13  SubCat1         12526 non-null  object
# dtypes: float64(3), int64(3), object(8)
# memory usage: 1.5+ MB

# %% [markdown]
# `Here as you can see there are more missing categorical values. `
# - Filling it with the common class/values.

# %%
df_ = df.apply(lambda x: x.fillna(x.value_counts().index[0]))

# %%
df_.isnull().sum()
# Out:
# Typeofsales       0
# Patient_ID        0
# Specialisation    0
# Dept              0
# Dateofbill        0
# Quantity          0
# ReturnQuantity    0
# Final_Cost        0
# Final_Sales       0
# RtnMRP            0
# Formulation       0
# DrugName          0
# SubCat            0
# SubCat1           0
# dtype: int64

# %% [markdown]
# # Data Visualization
# ---
# ## UNIVARIATE ANALYSIS
#
# ---
# ### Categorical data

# %%
sns.countplot(x =df_['Typeofsales'])
# Out:
# <Axes: xlabel='Typeofsales', ylabel='count'>

# %%
df_['Specialisation'].value_counts()
# Out:
# Specialisation4     3999
# Specialisation7     2098
# Specialisation3      734
# Specialisation2      609
# Specialisation8      594
# Specialisation20     554
# Specialisation11     516
# Specialisation16     509
# Specialisation1      440
# Specialisation14     436
# Specialisation5      390
# Specialisation21     360
# Specialisation26     342
# Specialisation6      251
# Specialisation23     249
# Specialisation25     201
# Specialisation31     184
# Specialisation17     178
# Specialisation9      158
# Specialisation15     143
# Specialisation42     132
# Specialisation27     117
# Specialisation10     107
# Specialisation50     100
# Specialisation33      99
# Specialisation55      91
# Specialisation43      74
# Specialisation45      55
# Specialisation34      53
# Specialisation39      47
# Specialisation41      44
# Specialisation40      43
# Specialisation28      34
# Specialisation19      30
# Specialisation48      24
# Specialisation61      23
# Specialisation12      23
# ...

# %%
sns.countplot(data = df_, x = "Specialisation")
# Out:
# <Axes: xlabel='Specialisation', ylabel='count'>

# %%
df['Dept'].value_counts().plot(kind = 'pie', autopct = "%.2f")
# Out:
# <Axes: ylabel='Dept'>

# %%
df_["Formulation"].value_counts().plot(kind = 'pie', autopct = "%.2f")
# Out:
# <Axes: ylabel='Formulation'>

# %%
#Similarly formulation can also be applied for bar graph
sns.countplot(x = df_['Formulation'])
# Out:
# <Axes: xlabel='Formulation', ylabel='count'>

# %%
df_["DrugName"].value_counts()
# Out:
# SODIUM CHLORIDE IVF 100ML                                                   2272
# SODIUM CHLORIDE 0.9%                                                         526
# MULTIPLE ELECTROLYTES 500ML IVF                                              467
# ONDANSETRON 2MG/ML                                                           444
# PANTOPRAZOLE 40MG INJ                                                        441
#                                                                             ...
# BASILIXIMAB 20 MG                                                              1
# MULTIVITAMIN + MULTIMINERAL + ANTIOXIDANTS + METHYLCOBALAMIN 200ML SYRUP       1
# ROPINIROLE 0.5MG TAB                                                           1
# IRON SUCROSE 100MG INJ                                                         1
# FENTANYL 12.5MCG/HR                                                            1
# Name: DrugName, Length: 751, dtype: int64

# %%
df_["SubCat"].value_counts()
# Out:
# INJECTIONS                      8168
# IV FLUIDS, ELECTROLYTES, TPN    2709
# TABLETS & CAPSULES              1505
# INHALERS & RESPULES              469
# OINTMENTS, CREAMS & GELS         364
# LIQUIDS & SOLUTIONS              265
# SYRUP & SUSPENSION               237
# POWDER                           216
# NUTRITIONAL SUPPLEMENTS          126
# PESSARIES & SUPPOSITORIES         55
# DROPS                             53
# VACCINE                           19
# SPRAY                             12
# PATCH                             11
# LOTIONS                            5
# SOLUTION                           3
# SACHETS                            1
# Name: SubCat, dtype: int64

# %%
sns.countplot(x = df_["SubCat"])
# Out:
# <Axes: xlabel='SubCat', ylabel='count'>

# %%
df_['SubCat'].value_counts().plot(kind = 'pie', autopct = '%.2f')
# Out:
# <Axes: ylabel='SubCat'>

# %%
df_['SubCat'].mode()
# Out:
# 0    INJECTIONS
# Name: SubCat, dtype: object

# %%
df_['SubCat1'].value_counts()
# Out:
# INTRAVENOUS & OTHER STERILE SOLUTIONS                                 4884
# GASTROINTESTINAL & HEPATOBILIARY SYSTEM                               1738
# ANTI-INFECTIVES                                                       1647
# CARDIOVASCULAR & HEMATOPOIETIC SYSTEM                                 1480
# CENTRAL NERVOUS SYSTEM                                                1262
# RESPIRATORY SYSTEM                                                     593
# ANAESTHETICS                                                           591
# NUTRITION                                                              331
# MUSCULO-SKELETAL SYSTEM                                                322
# VITAMINS & MINERALS                                                    303
# HORMONES                                                               291
# IMMUNOLOGY                                                             186
# ...

# %%
df_['SubCat1'].mode()
# Out:
# 0    INTRAVENOUS & OTHER STERILE SOLUTIONS
# Name: SubCat1, dtype: object

# %% [markdown]
# ### Numerical Data

# %%
#Quantity
plt.subplot(2, 2, 1)
sns.histplot(df_['Quantity'])

plt.subplot(2,2,2)
sns.distplot(x = df_['Quantity'])

plt.subplot(2,2,3)
sns.boxplot(df['Quantity'])

plt.subplot(2,2,4)
sns.violinplot(df['Quantity'])
# Out:
# <ipython-input-135-069be78fafb4>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x = df_['Quantity'])
# <Axes: ylabel='Quantity'>

# %%
# Final Cost

plt.subplot(2, 2, 1)
sns.histplot(df_['Final_Cost'])

plt.subplot(2,2,2)
sns.distplot(x = df_['Final_Cost'])

plt.subplot(2,2,3)
sns.boxplot(df['Final_Cost'])

plt.subplot(2,2,4)
sns.violinplot(df['Final_Cost'])
# Out:
# <ipython-input-137-9424c1dd8216>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x = df_['Final_Cost'])
# <Axes: ylabel='Final_Cost'>

# %% [markdown]
# `Similarly, for the ReturnQuantity and RTNMrp the graphs will be plotted for the Univariate Analysis`

# %% [markdown]
# ## Bi-Variate Analysis
#
# ### Numerical_Categorical Both

# %%
plt.figure(figsize=(15,11))
sns.barplot(y = 'Specialisation', x= "Quantity", data = df_)
# Out:
# <Axes: xlabel='Quantity', ylabel='Specialisation'>

# %%
plt.figure(figsize=(15,11))
sns.barplot(y = 'Specialisation', x= "ReturnQuantity", data = df_)
# Out:
# <Axes: xlabel='ReturnQuantity', ylabel='Specialisation'>

# %%
plt.figure(figsize=(15,11))
sns.barplot(y = 'Specialisation', x= "Final_Sales", data = df_)
# Out:
# <Axes: xlabel='Final_Sales', ylabel='Specialisation'>

# %%
plt.figure(figsize=(15,11))
sns.barplot(y = 'Specialisation', x= "Final_Cost", data = df_)
# Out:
# <Axes: xlabel='Final_Cost', ylabel='Specialisation'>

# %%
plt.figure(figsize=(15,11))
sns.barplot(y = 'Specialisation', x= "RtnMRP", data = df_)
# Out:
# <Axes: xlabel='RtnMRP', ylabel='Specialisation'>

# %% [markdown]
# ### Numerical data

# %%
plt.figure(figsize=(15,11))
sns.scatterplot(x = "Final_Sales", y = "Final_Cost" , hue = "Patient_ID", data = df_)
# Out:
# <Axes: xlabel='Final_Sales', ylabel='Final_Cost'>

# %% [markdown]
# - Plotting the final HEATMAP As the above heatmap shows false distribution of the Categorical Data. Therefore after te data cleaning plotting the final `HEATMAP`.

# %%
#Plotting for the 2 categorical values
x = pd.crosstab(df_['SubCat1'], df_['Formulation'])
sns.heatmap(x, annot = True)
# Out:
# <Axes: xlabel='Formulation', ylabel='SubCat1'>

# %%
#After preprocessing all the column the final mode for the categorical value:
#Mode value for the categorical Value
data_cat = {
    'column_name' : ['Formulation', 'DrugName' , 'SubCat' , 'SubCat1'],
    'Mode_categorical' : [df_['Formulation'].mode(), df_['DrugName'].mode(), df_['SubCat'].mode(), df_['SubCat1'].mode]
}

mode_cat = pd.DataFrame(data_cat)
mode_cat
# Out:
#    column_name                                   Mode_categorical
# 0  Formulation        0    Form1
# Name: Formulation, dtype: object
# 1     DrugName  0    SODIUM CHLORIDE IVF 100ML
# Name: DrugName,...
# 2       SubCat        0    INJECTIONS
# Name: SubCat, dtype: object
# 3      SubCat1  <bound method Series.mode of 0                ...

# %%
df['SubCat1'].mode()
# Out:
# 0    INTRAVENOUS & OTHER STERILE SOLUTIONS
# Name: SubCat1, dtype: object

# %% [markdown]
# # Conclusion
# ---
# We had completed all the key points.
#
# i> Calculated all the 4 Moment of Business Decisions for the required column for the insights.
#
# ii> Done the  Univariate and Multivariate Graphical as well s non-graphical analysis.
#
# iii> And Finally solved the missing values.
#
# iv> Also after removing all the estimated outliers the readings of the 4 moment of business decision is added on the excel file attached to it.

# %% [markdown]
# # USEFUL INSIGHTS:
# ------
# i> Specialisation54 contains highest RtnMRP : MRP of returned drug (Quantity included) as well as Highest ReturnQuantity
#
# ii> Specialisation41 contains highest Final_Cost and Final_Sales
#
# iii> Specialisation8 contains highest Quantity
# Similarly after go throughing all possible combination,
#
# Therefore, Here we can understand that around 20 plus percent of customer in the data set based on a situation where they returned medicine with a final_sales value of zero this means that a significant portion of our customer did not get the  medicine they needed which could lead to dissatisfaction of a customer so to improve business criteria we can increase our revenue and its important to reduce the bounce rate by ensuring customer service at is best

# %%
# sns.barplot(x = df[df['Final_Sales']==0]['Patient_ID'], y = df[df['Typeofsales']=='return']['Patient_ID'], hue = df['Patient_ID'])
